# %% [markdown]
# ### Question: 01
#     Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Muhammad Zukhruf\nHabib ur Rehman\n08:18:2006")
# Out:
# Muhammad Zukhruf
# Habib ur Rehman
# 08:18:2006

# %%
name=("\"Muhammad Zukhruf\"")
f_name=("\"Habib ur Rehman\"")
dob=("\"18:08:2006\"")

print(f"My name is {name}.\nMy Father name is {f_name}.\nMy DOB is {dob}.")
# Out:
# My name is "Muhammad Zukhruf".
# My Father name is "Habib ur Rehman".
# My DOB is "18:08:2006".
