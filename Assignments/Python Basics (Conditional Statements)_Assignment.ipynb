# %% [markdown]
# ## Question: 01
#
#     A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years. Ask user for their salary and year of service and print the net bonus amount.

# %%
user_name = input("Enter your name")
user_salary = int(input("Enter your Current Salary in Digits :"))
yo_service = int(input("Enter your Year Of Service in Digits :"))

# %%
def bonus_calculator(salary, name, service):
    if yo_service > 5:
        salary_cal = user_salary * 0.05
        final_slary = user_salary + salary_cal
        return f"Hey! {name}, Your total years of service is {service}, current salary is {salary} and total bonus amount is {salary_cal}, so total salary is {final_slary}."
    
    else:
        return f"Hey! {name}, we are really sorry you didn't get any bonus. Your service years didn't match criteria. Current service year's {service}"
    
    
    
    
bonus_calculator(salary=user_salary, name=user_name, service=yo_service)

# %% [markdown]
# ## Question: 02
#     Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible.

# %%
user_age = int(input("Enter Your age :"))

# %%
waiting_age = 18 - user_age

# %%
if user_age >= 18:
    print("You are eligible for voting.")
else:
    print(f"You're not eligible for voting. You need to wait {waiting_age} years.")

# %% [markdown]
# ## Question: 03
#     Write a program to check whether a number entered by user is even or odd.

# %%
num = int(input("Enter your number to check wheater number is even or odd :"))

# %%
if num % 2:
    print("number is odd")
else: 
    print("Number is even")

# %% [markdown]
# ## Question: 04
#     Write a program to check whether a number is divisible by 7 or not. Show Answer.

# %%
nums = int(input("Enter Your Number :"))
check_num = nums % 7

# %%
if check_num == 0:
    print("Number is divisible by 7")
else: 
    print("Number is not divisible by 7")

# %% [markdown]
# ## Question: 05
#     Write a program to display "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
numb = int(input("Enter Your Number :"))

# %%
if numb % 5:
    print("Bye!")
else: 
    print("Hello!")

# %% [markdown]
# ## Question: 06
#     Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria : Unit Price
#     uptp 100 units no charge Next 200 units Rs 5 per unit After 200 units Rs 10 per unit (For example if input unit is 350 than total bill amount is Rs.3500 (For example if input unit is 97 than total bill amount is Rs.0 (For example if input unit is 150 than total bill amount is Rs.750

# %%
def unit_cal(unit):
    if unit >= 0 and unit <=100:
        bill = 0 * unit
        return f"Your bill is RS{bill}"
    
    elif unit > 100 and unit <=300:
            bill = 5 * unit
            return f"Your bill is RS{bill}"
        
    elif unit > 300:
                bill = 10 * unit
                return f"Your bill is RS : {bill}"
    else:
        return "Invalid! input"

# %%
print(unit_cal(int(input("Enter the units :"))))

# %% [markdown]
# ## Question: 07
#     Write a program to display the last digit of a number.

# %%
user_in = (int(input("Enter the units :")))

cal = user_in % 10

print(cal)

# %% [markdown]
# ## Question: 08
#     Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = (int(input("Enter the length :")))
breadth = (int(input("Enter the breadth :")))

# %%
if length == breadth and length > 0 and breadth >0:
    print("It's a Square")
elif length != breadth and length > 0 and breadth >0:
    print("It's a Rectangle")
else:
    print("Invalid! input")

# %% [markdown]
# ## Question: 09
#     Take two int values from user and print greatest among them.

# %%
value_one = (int(input("Enter the first value :")))
value_two = (int(input("Enter the second value :")))

# %%
if value_one > value_two :
    print(f"Biggest value is {value_one}")
elif value_one < value_two:
    print(f"Biggest value is {value_two}")
elif value_one == value_two:
    print("Both values are equal")
else:
     print("Invalid! input")

# %% [markdown]
# ## Question: 10
#     A shop will give discount of 10% if the cost of purchased quantity is more than 1000. Ask user for quantity Suppose, one unit will cost 100. Judge and print total cost for user.

# %%
item_quan = (int(input("Enter the quantity :")))

# %%
cost = item_quan * 100

if cost > 1000 :
    dis_cal = cost * 0.10
    final_cost = cost - dis_cal
    print(f"Your Total Amount is RS {final_cost} ")
else: 
    print(f"Your Total Amount is RS {cost}")
    
print(dis_cal)

# %% [markdown]
# ## Question: 11
#
#     A school has following rules for grading system:
#
#     a. Below 25 - F
#
#     b. 25 to 45 - E
#
#     c. 45 to 50 - D
#
#     d. 50 to 60 - C
#
#     e. 60 to 80 - B
#
#     f. Above 80 - A
#
#     Ask user to enter marks and print the corresponding grade.

# %%
def grade_cal(marks):
    if marks < 25 :
        return "Your Grade is F"
    elif marks >= 25 and marks < 45 :
        return "Your Grade is E"
    elif marks >= 45 and marks < 50 :
        return "Your Grade is D"
    elif marks >= 50 and marks < 60 :
        return "Your Grade is C"
    elif marks >= 60 and marks < 80 :
        return "Your Grade is B"
    elif marks >= 80:
        return "Your Grade is A"

# %%
marks = (int(input("Enter the Marks :")))
grade_cal(marks)

# %% [markdown]
# ## Question:12
#     Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
def age_cal(a,b,c):
    old = max(a,b,c)
    young = min (a,b,c)
    return f"The oldest is {old} and youngest is {young}"

# %%
a = (int(input("Enter the AGE :")))
b = (int(input("Enter the AGE :")))
c = (int(input("Enter the AGE :")))

# %%
age_cal(a=a,b=b,c=c)

# %% [markdown]
# ## Question: 13
#     A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
#     Take following input from user
#
#         Number of classes held
#
#         Number of classes attended.
#
#     And print
#
#         percentage of class attended
#
#         Is student is allowed to sit in exam or not.

# %%
total_classes = (int(input("Enter the total classes held :")))
while total_classes <= 0:
    print("Total classes must be greater than 0!")
    total_classes = int(input("Please enter valid total classes held: "))
    
attended_classes = (int(input("Enter total classes attended")))

# %%
per_classes = (attended_classes / total_classes)*100
if per_classes >= 75 :
        print(f"your total attendece is {per_classes}%\nCongragulation you can sit in exams")
    
else:
        print(f"your total attendece is {per_classes}%\nSorry! you can't sit in exams")
# Out:
# your total attendece is 50.0%
# Sorry! you can't sit in exams

# %% [markdown]
# ## Question: 14
#     Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
if per_classes >= 75:
    print(f"your total attendece is {per_classes}\nCongragulation you can sit in exams.")
    
else:
    print("your attendence is lower then 75%.\nDo you have any Medical Cause?\nIf yes type 'Y' and if no type 'N'")
    medical_cause = input("Enter (Y/N)").strip().upper()
    if medical_cause == "Y":
        print(f"your total attendece is {per_classes}\nCongragulation you can sit in exams because you have medical cause.")
    elif medical_cause == "N":
        print(f"your total attendece is {per_classes}%\nSorry! you can't sit in exams.")
# Out:
# your attendence is lower then 75%.
# Do you have any Medical Cause?
# If yes type 'Y' and if no type 'N'
# your total attendece is 50.0%
# Sorry! you can't sit in exams.

# %% [markdown]
# ## Question: 15
#
#     Write a program to check if a year is leap year or not.
#
#         If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("Enter the year :"))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(f"{year} is a Leap Year")
else:
    print(f"{year} is not a Leap Year")
# Out:
# 1900 is not a Leap Year

# %% [markdown]
# ## Question:16
#
#     Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
#     if employee is female, then she will work only in urban areas.
#
#     if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
#     if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
#     And any other input of age should print "ERROR"

# %%
age = int(input("Enter Age :"))
gender = input("Enter Gender (M/F) :").strip().upper()
marital_status = input("Enter Marital Status (Y/N) :").strip().upper()

# %%
if age < 20 or age > 60 :
    print("Error")
elif gender == "F" :
    print("You can only work in urban areas")
elif gender == "M" and age >= 20 and age < 40 :
    print("You can work anywhere")
elif gender == "M" and age >= 40 and age <= 60 :
    print("You can only work in urban areas")
else:
    print("Error")
# Out:
# You can only work in urban areas
